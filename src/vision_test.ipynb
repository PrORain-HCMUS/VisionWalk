# %%
from pydantic import BaseModel
from PIL import Image
import base64
import google.generativeai as genai
import os
from IPython.display import display
import IPython.display as dp

# %%
genai.configure(api_key="AIzaSyDP4HLTC9pSCCdSCpB5DqmMbZMrOVoYF9I")
model = genai.GenerativeModel(model_name="gemini-1.5-flash")

# %%
def generate_text_of_img(img_path):
    img = Image.open(img_path)

    prompt = """Hãy mô tả môi trường xung quanh như đang hướng dẫn một người khiếm thị, tập trung vào:
    1. Các chướng ngại vật (ví dụ: đống cát, gạch đá, rãnh nước, cột điện, xe đạp...)
    2. Biển báo và biển chỉ dẫn
    3. Các vật có thể gây nguy hiểm
    4. Điều kiện mặt đường (ví dụ: trơn trượt, gồ ghề, có nước...)
    
    Cho mỗi vật thể/yếu tố, hãy:
    - Xác định vị trí tương đối (trước mặt, bên trái, bên phải)
    - Ước lượng khoảng cách từ vị trí người quan sát (càng chính xác càng tốt, nếu không chắc chắn thì cho biết khoảng)
    - Mức độ nguy hiểm hoặc ảnh hưởng đến việc di chuyển
    
    Trả lời bằng giọng điệu tự nhiên, như đang nói chuyện trực tiếp với người khiếm thị. 
    Nếu có yếu tố nguy hiểm cần đặc biệt chú ý, hãy nhấn mạnh điều đó.
    Không thêm định dạng văn bản hay nội dung không cần thiết."""

    response = model.generate_content([img, prompt])

    return (response.text)

# %%
folder_path = '../assets/img/street_test'
for file_name in os.listdir(folder_path):
    file_path = os.path.join(folder_path, file_name)
    display(dp.Image(filename=file_path))
    print(generate_text_of_img(file_path))
# Out:
# Mình sẽ mô tả môi trường xung quanh cho bạn nhé. Trước mặt bạn là một con đường nhựa khá bằng phẳng, tuy nhiên có những vạch kẻ đường hơi mờ, bạn cần chú ý bước đi cẩn thận để tránh bị vấp. Khoảng cách từ bạn đến lề đường bên phải là khoảng 1 mét, trên lề đường này có một chiếc ghế thấp đặt cạnh một biển hiệu bằng bìa cứng có chữ viết,  dường như là thông báo không được đậu xe, khoảng cách đến biển này là 2 mét.  Bên phải, sát lề đường có một vài chướng ngại vật nhỏ, như một đống rác nhỏ và một vài bụi cây, bạn cần đi chậm để tránh vấp phải chúng.  Khoảng cách từ bạn đến những bụi cây này là tầm 1,5 mét.  Xa hơn một chút, ở phía bên phải, có một chiếc xe máy đang dựng sát vách tường, bạn cần tránh xa chiếc xe này khoảng 3 mét để đảm bảo an toàn.  Phía trước, cách bạn tầm 10 mét là một giao lộ, bạn cần lưu ý quan sát và nghe ngóng xem có xe cộ nào đang di chuyển không trước khi băng qua đường.  Trên đường có một số xe máy và ô tô đang đỗ, nhớ chú ý tránh xa chúng.  Mặt đường nhìn chung khá khô ráo, nhưng vẫn cần cẩn thận nếu trời mưa vì có thể hơi trơn.  Hãy đi chậm rãi và chú ý quan sát xung quanh nhé.
# Được rồi, mình sẽ hướng dẫn bạn. Trước mặt bạn là mặt đường nhựa, tương đối bằng phẳng nhưng hơi tối, nên cẩn thận bước đi nhé. Khoảng 1 mét trước mặt bạn có một cục đá khá lớn, nằm ngay mép đường,  có thể gây vấp ngã nếu không để ý, nên tránh xa nó.  Cùng với cục đá là một đoạn dây điện nằm trên đường,  khoảng cách cũng tầm 1 mét,  bạn cần cẩn thận bước qua hoặc tránh để khỏi bị vấp.
#
# Bên phải bạn, cách khoảng 2 mét là một vỉa hè, có một rãnh thoát nước nhỏ.  Cẩn thận khi bước lên vỉa hè, tránh bị trượt chân.  Trên vỉa hè có một chậu cây khá lớn, khoảng cách từ bạn là 3 mét.  Gần đó có một cột đèn, khoảng 4 mét, cột được sơn màu đỏ trắng. Trên cột có một biển báo bằng giấy viết chữ “Không đỗ xe trước cửa nhà”, bạn cần lưu ý điều này để tránh bị phạt.
#
# Ngay sát cột đèn, bên phải, là một bụi cây nhỏ.
#
# Trên đường, phía trước bạn,  khoảng cách 5 mét có một vài chiếc xe máy đậu bên vệ đường.  Cần giữ khoảng cách an toàn để tránh bị va chạm.  Mặt đường nhìn chung không có gì nguy hiểm lắm, nhưng vẫn nên đi chậm rãi, để ý từng bước chân.  Chúc bạn di chuyển an toàn!
# Được rồi, mình sẽ hướng dẫn bạn nhé. Bạn đang đứng trên một con đường nhựa, mặt đường tương đối bằng phẳng, không có vẻ trơn trượt hay có nước.
#
# Ngay trước mặt bạn, cách khoảng 1 mét, là một đống cát khá lớn, cao khoảng nửa mét. Bạn cần phải đi vòng qua nó, vì nó chắn ngang đường đi.  Mức độ nguy hiểm: trung bình, có thể vấp ngã nếu không chú ý.
#
# Bên phải bạn, cách khoảng 2 mét, là một vài chiếc xe máy đậu sát lề đường.  Bạn cần lưu ý khi đi qua để tránh va chạm. Mức độ nguy hiểm: trung bình.
#
# Bên trái bạn, cách khoảng 5 mét, là một số quầy hàng nhỏ.  Không có gì quá nguy hiểm ở khu vực này, nhưng hãy đi chậm để tránh va chạm nếu có người đi lại.
#
# Phía trước, hơi lệch bên phải một chút, cách khoảng 10 mét, có một biển hiệu phía trên một quầy hàng. Tôi không thể đọc được nội dung trên biển hiệu đó nhưng nó có thể chỉ dẫn đến một cửa hàng nào đó.
#
# Dọc theo con đường có một số cột điện, cách xa bạn khoảng từ 10 đến 20 mét. Chúng không gây nguy hiểm trực tiếp nếu bạn không đi quá gần.
#
# Tổng thể, con đường tương đối an toàn. Tuy nhiên, hãy đi chậm rãi và chú ý quan sát để tránh những chướng ngại vật như đống cát. Cẩn thận với xe máy phía bên phải và người đi lại gần các quầy hàng bên trái.  Nếu bạn cần sự trợ giúp, cứ gọi nhé!
# Được rồi, mình sẽ hướng dẫn bạn.  Hiện tại trời đang mưa, đường khá trơn.
#
# Trước mặt bạn khoảng 5 mét là mặt đường khá trơn ướt, nên đi chậm thôi nhé.  Ngay giữa đường, hơi lệch về bên phải một chút, cách bạn khoảng 4 mét có một người đi xe máy, bạn cần chú ý quan sát để tránh va chạm.  Bên phải đường, cách bạn khoảng 2 mét là một con đường nhỏ dẫn vào một khu nhà, có vẻ như có nhiều cây cối và khá nhiều đất đá, có thể có rễ cây nhô lên, bạn cần cẩn thận. Cũng ở bên phải, gần sát đường, có một cây khá to, cành cây rủ xuống thấp.  Khoảng cách từ bạn đến cây này là tầm 1 mét.
#
# Bên trái đường, cách bạn chừng 7 mét có một cổng vào, dường như có một cái nhà.  Đường bên trái có vẻ sạch sẽ hơn nhưng vẫn hơi trơn ướt.
#
# Trên đường có vạch kẻ đường màu vàng, bạn có thể dùng nó làm mốc.  Trên đường có vài biển báo, nhưng do điều kiện thời tiết nên mình không thể xác định chính xác nội dung được. Nói chung, bạn nên đi thật chậm rãi, chú ý quan sát xung quanh, tránh xa những nơi có đất đá, rễ cây và cành cây. Đường trơn, nên đi thật cẩn thận để tránh té ngã. Mưa khá to, tầm nhìn có thể bị hạn chế. Hãy luôn chú ý đến tiếng động xung quanh để nắm bắt tình hình giao thông.
# Được rồi, mình sẽ hướng dẫn bạn nhé.
#
# Trước mặt bạn là một đoạn đường nhựa, nhìn chung khá bằng phẳng nhưng có một số vết lún nhỏ, không quá nguy hiểm nhưng nên đi chậm rãi.  Khoảng cách xa tầm 10 mét về phía trước, có một tấm thảm trải trên mặt đường, bạn cần chú ý để không bị vấp ngã. Tấm thảm khá lớn, khoảng 1-1,5m vuông.
#
# Bên phải bạn là một chiếc xe tải đang đỗ, cách bạn khoảng 5 mét. Phía sau xe tải có một đống ống nhựa, không gây nguy hiểm nhưng nên giữ khoảng cách an toàn.  Cùng bên phải,  cách khoảng 7-8 mét có một vài chiếc xe máy đang đỗ, cần chú ý để tránh va chạm.
#
# Bên trái bạn, cách tầm 10-12 mét có một số xe khác đang đậu.
#
# Trên đường có nhiều biển báo, quảng cáo, cách bạn từ 5 đến 15 mét, nhưng chúng không trực tiếp cản trở đường đi.  Tuy nhiên cần chú ý những biển này để tránh việc va chạm hoặc làm người khác khó chịu.
#
# Phía trước, cách khoảng 15 mét có một vài người đang đứng gần hai chiếc xe máy nằm nghiêng trên đường, có vẻ như có tai nạn xảy ra ở đó.  **Đây là khu vực nguy hiểm, bạn cần đặc biệt chú ý, di chuyển chậm và thận trọng.**  Cần giữ khoảng cách an toàn.
#
# Nhìn chung, mặt đường tương đối khô ráo. Tuy nhiên, vẫn cần cẩn thận vì có thể có những mảnh vỡ nhỏ hoặc vật cản khác trên đường mà mình không nhìn thấy hết được.  Hãy đi chậm rãi, dùng gậy để thăm dò mặt đường phía trước khi đi.
# Được rồi, mình sẽ mô tả môi trường xung quanh cho bạn.
#
# Trước mặt bạn là một đoạn đường khá rộng, mặt đường bằng phẳng nhưng có nhiều mảnh vỡ từ vụ tai nạn,  gồm kính, mảnh nhựa, và kim loại.  Một số mảnh vỡ có kích thước khá lớn, nằm rải rác trên đường, cách bạn khoảng 1-2 mét.  Đây là những chướng ngại vật nguy hiểm, bạn cần bước thật cẩn thận để tránh bị vấp ngã hoặc bị thương. Có vũng nước nhỏ trên đường, khoảng 50cm trước mặt bạn, dễ gây trơn trượt.
#
# Bên phải bạn, cách khoảng 3 mét là một chiếc xe hơi bị hư hỏng nặng do tai nạn, nằm nghiêng trên sườn dốc cỏ.  Xe nằm khá gần mép đường, có thể có thêm mảnh vỡ rơi xuống từ xe, gây nguy hiểm.  Sườn dốc cỏ dốc xuống khá cao, bạn không nên đến gần khu vực đó.
#
# Bên trái bạn, cách khoảng 1 mét là một chiếc xe tải lớn đang đỗ.  Bạn cần chú ý giữ khoảng cách an toàn để tránh bị va chạm.
#
# Trên đường, cách bạn khoảng 20 mét là một biển báo màu xanh lá cây, có chữ viết và số, có vẻ như là bảng chỉ dẫn đường.  Mình không thể đọc được thông tin cụ thể nhưng nó có thể hữu ích nếu bạn cần định hướng.
#
# Cảnh báo:  Khu vực này rất nguy hiểm do vừa xảy ra tai nạn.  Nhiều mảnh vỡ sắc nhọn trên mặt đường và trên sườn dốc.  Hãy đi lại chậm rãi, thận trọng và đặt chân xuống chắc chắn để tránh bị thương. Hãy cẩn thận với vũng nước có thể gây trơn trượt.
# Mình đang hướng dẫn bạn nhé. Trước mặt bạn là một con đường đất khá xấu. Mặt đường gồ ghề, nhiều ổ gà và vũng nước đọng, nên rất trơn trượt, nguy hiểm khi di chuyển.  Khoảng cách từ bạn đến vũng nước gần nhất là khoảng 2 mét.  Bạn cần đi rất cẩn thận.
#
# Ngay trước mặt bạn, khoảng 1 mét, là một đoạn đường đất nhô cao tạo thành gờ, tương đối nhỏ nhưng vẫn gây khó khăn khi đi xe.
#
# Bên phải đường, cách bạn chừng 5 mét, có một hàng cây bụi rậm rạp, không gây cản trở nhưng bạn nên chú ý để tránh bị vướng vào cành cây.
#
# Bên trái, cũng cách khoảng 5 mét, có một hàng rào nhỏ, không nguy hiểm lắm.
#
# Phía xa xa bên phải, khoảng 20 mét, có vài chiếc cột điện. Chúng không nằm trên đường đi nên không gây nguy hiểm trực tiếp, nhưng bạn nên nhớ đến để tránh trường hợp bất ngờ.
#
# Trên đường đi có một người đàn ông đang đi xe máy, xe cách bạn khoảng 5 mét. Bạn cần chú ý quan sát để tránh va chạm. Đường rất trơn, rất dễ ngã. Hãy đi chậm và thật cẩn thận nhé.  Lưu ý đặc biệt với các vũng nước, chúng rất trơn và có thể khiến bạn bị ngã.
# Mình đang mô tả cho bạn môi trường xung quanh nhé. Trước mặt bạn là một con đường nhựa, khá bằng phẳng. Tuy nhiên, giữa đường có một lớp thóc vàng trải rộng, dày khoảng 10cm, chiếm gần hết chiều rộng đường.  Cẩn thận nhé, vì lớp thóc này có thể gây trơn trượt. Khoảng cách từ bạn đến lớp thóc này tầm 5 mét.  Bên cạnh lớp thóc có hai thùng rác màu xanh lá cây, đặt cách nhau khoảng 1 mét, cách bạn khoảng 4 mét.  Phía trước, xa hơn chút nữa, có một người đang quét dọn thóc.
#
# Bên phải đường, có một vỉa hè, nhưng có nhiều cây cối rậm rạp.  Bên trái đường, cũng có vỉa hè và nhà cửa.  Phía sau bạn, cách khoảng 2 mét là một chiếc xe máy đang đậu.
#
# Trên đường có vài chiếc xe máy đỗ ở xa.  Không có biển báo hay biển chỉ dẫn nào gần đây cả.  Nhìn chung, mặt đường khô ráo, ngoại trừ phần thóc trải ra.  Chú ý nhất là lớp thóc trải trên đường nhé, nó khá trơn và có thể gây vấp ngã.  Bạn nên đi chậm và cẩn thận khi đi qua khu vực này.
# Mời bạn nghe nhé. Bạn đang đứng trên vỉa hè, mặt đường khá bằng phẳng, không có gì trơn trượt hay gồ ghề.
#
# Ngay trước mặt bạn, cách khoảng 1 mét, là một rãnh thoát nước nhỏ.  Hãy cẩn thận bước qua nhé.
#
# Bên phải bạn, khoảng 2 mét, có một chiếc xe hơi đỗ sát lề.  Chừa khoảng cách an toàn để tránh va chạm.  Cũng ở bên phải, song song với vỉa hè, nhưng xa hơn một chút,  có một hàng cây, khoảng 3 mét. Không có gì nguy hiểm ở khu vực này.
#
# Bên trái bạn, cách khoảng 1,5 mét có một chiếc xe hơi khác cũng đỗ sát lề đường. Hãy lưu ý vị trí của nó để không va vào.
#
# Trên vỉa hè, ngay trước mặt bạn, có các cột biển báo. Ở ngay phía trước, cách khoảng 50cm, là biển báo cấm xe tải từ 16 chỗ trở lên vào. Tiếp theo, là biển chỉ dẫn nơi đỗ xe, với hình ô tô và xe đạp, chỉ rõ khu vực đỗ xe dành cho ô tô và xe đạp.  Hãy lưu ý các thông tin này để tìm chỗ đỗ xe phù hợp.
#
# Phía xa hơn một chút, khoảng 10 mét, đường giao thông có các phương tiện đang lưu thông.  Lưu ý nghe ngóng tiếng xe cộ để tránh nguy hiểm khi đi bộ qua đường.
#
# Nhìn chung, vỉa hè này tương đối an toàn.  Hãy đi chậm rãi và cẩn thận quan sát, nhất là khi đi qua rãnh nước và lưu ý các phương tiện giao thông.
